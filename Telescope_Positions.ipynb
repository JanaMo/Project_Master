# %% [markdown]
# ## North or South ? Where to follow up ?
# Site selection for the usage of the tool

# %%
import matplotlib.pyplot as plt 
% matplotlib inline

import pandas as pd
import numpy as np


from astropy.io import fits  ## pip install astropy --no-deps 
from astropy import units as u 
from astropy.coordinates import Angle

from mpl_toolkits.basemap import Basemap ## conda install basemap 
from collections import OrderedDict

# %% [markdown]
# ## Follow up possibilities
# Map of potential ground-based Follow-Up facilities
# - optical
# - radio
# - neutrino
# - cosmic rays
# - gamma-rays
#
# See generally more telescopes on northern site

# %%
## Optical telescopes > 4 m aperture 
Obs = np.array(['La Palma, Canary Islands : Gran Telescopio Canarias',
               'MCDonals Obs. Texas, USA: Hobby-Eberly_Telescope',
               'Mauna Kea Obs. Hawaii, USA: KECK 1&2',
               'Northern Cape, South Africa: Southern African Large Telescope, ',
               'Mount Graham Int. Obs. Arizona, USA: Large Binocular Telescope',
                'Mauna Kea Obs. Hawaii, USA: Subaru',
                'Paranal, Chile : VLT UT 1-4',
                'Manua Kea Obs. hawaii, USA: Gemini North',
                'Cerro Pachon Coquimbo, Chile: Gemini South',
                'Whipple Obs. Arizona, USA: MMT',
                'Las Campamas Obs, Coquimbo Chile : Magellan 1&2',
                'Special Astrophys. Obs. Karachay, Russia: BTA-6',
                'Maple Ridge, Canada: Large Zenith Telescope',
                'Palomar Observatory California, USA: Hale Telescope',
                'Bejing Astronomical Obs. Xinglong, China: LAMOST',
                'Lowell Obs. Arizona, USA', 
                'La Palma, Canary Islands : William Herschel Telescope',
                'Cerro Pachon Coquimbo, Chile: SOAR',
                'Paranal, Chile : VISTA',
                'Kitt Peak National Arizona, USA: Nicholas Mayall 4m ', 
                'Asutralian Astronomical, New South Wales, Australia', 
                'Air Force Maui Optical Station Hawaii, USA: 3.67 m AEOS Telescope',
                'ARIES obs. Naintal, India',   
               ])

Lambda = np.array(['Optical', 'Optical', 'Optical', 'Optical', 'Optical', 'Optical','Optical', 'Optical',# Gemini Nord
                  'Optical','Optical', 'Optical ', 'Optical', 'Optical','Optical','Optical', ## Bejing China 
                  'Optical', 'Optical', 'Optical', 'Optical', 'Optical', 'Optical','Optical', ## AIr Force 
                 'Optical'])

## EAST ##
Lon = np.array([Angle('-16°53′5″')/u.deg, # Canaria 
                Angle('-104°01′19″')/u.deg, ## Texas
                Angle('-155°28′30″')/u.deg, ## Hawaii
                20.8105, ## South Africa 
                Angle('-109°53′31″')/u.deg, ## Arizona Graham 
                Angle('-154°28′30″')/u.deg, ## Hawaii
                Angle('-69°24′11″')/u.deg, ## Paranal 
                Angle('-156°28′30″')/u.deg, ## Hawaii
                Angle('-70°44′11.7″')/u.deg, ## Chile Cerro Pachon 
                Angle('-110°52′41″')/u.deg, ## Arizona Whipple 
                Angle('-70°41′31″')/u.deg, ## Chile Las Campamas 
                Angle('41°26′26″')/u.deg, ## Russia 
                Angle('-122°36′0″')/u.deg, ## Canada Marple 
                Angle('-116°51′54″')/u.deg, ## California 
                Angle('117°34′30″')/u.deg, ## Xinglong China 
                Angle('-111°39′52″')/u.deg, ## Arizona Lowell 
                Angle('-18°53′5″')/u.deg, # Canaria 
                Angle('-71°44′11.7″')/u.deg, ## Chile Cerro Pachon 
                Angle('-71°24′11″')/u.deg, ## Paranal 
                Angle('-111°35′48″')/u.deg, ## Arizona Kitt Peak
                Angle('149°04′00″')/u.deg, ## Australia 
                Angle('-154°28′30″')/u.deg, ## Hawaii Air Force 
                79.449, ## India
               ]) 
## NORTH ##
Lat = np.array([
                Angle('27°45′15″')/u.deg,# Canaria
                Angle('30°40′17″')/u.deg, # Texas 
                Angle('19°49′20″')/u.deg, ## Hawaii
                -32.3783, ## South Africa 
                Angle('32°42′05″')/u.deg, ## Arizona 
                Angle('18°49′20″')/u.deg, ## Hawaii
                Angle('-23°37′33″')/u.deg, ## Paranal 
                Angle('20°49′20″')/u.deg, ## Hawaii
                Angle('-30°14′26.6″')/u.deg, ## Chile Cerro Pachon 
                Angle('31°40′52″')/u.deg, ## Arizona Whipple 
                Angle('-29°00′57″')/u.deg, ## Chile Las Campamas 
                Angle('43°38′49″')/u.deg, ## Russia 
                Angle('49°13′0″')/u.deg, ## Canada Marple 
                Angle('33°21′21″')/u.deg, ## California 
                Angle('40°23′39″')/u.deg, ## Xinglong China 
                Angle('35°12′10″')/u.deg, ## Arizona Lowell 
                Angle('29°45′15″')/u.deg,# Canaria
                Angle('-29°14′26.6″')/u.deg, ## Chile Cerro Pachon 
                Angle('-25°37′33″')/u.deg, ## Paranal
                Angle('31°57′30″')/u.deg, ## Arizona Kitt Peak
                Angle('-31°16′36″')/u.deg, ## Australia 
                Angle('19°49′20″')/u.deg, ## Hawaii Air Force 
                29.395, ## India
               ])

df_Optical = pd.DataFrame(OrderedDict({'Observatory': Obs,'Wavelength': Lambda, 'Longitude_East': Lon, 'Latitude_North': Lat}))
#df_Optical    # print the List of telescopes with Lon/Lat

# %%
## Radio 
Obs = np.array([#Africa 
    'Kutunse,Ghana: AVN_Ghana',
    'Carnarvon, South Africa: C-BASS, MeerKAT,SKA,PAPER',
    'Hartebeesthoek, Johannesburg: HartRAO 26 m + 15 m',
    'Durban University, South Africa: Indlebe',
            #Antarctica 
    'Amundsen Scott Soutch Pole Station: DASI,SPT',
            # Asia 
    'Delingha, Qinghai: Delingha 13.7 m',
    'Shanghai Astronomical Observatory: Sheshan +Tian Ma 65 m ',
    'Miyun: MSRT + 50m Telescope',
    'Pune,India: Giant Metrewave 45m Radio telescope',
    'Ooty, India: Ooty Radio Telescope',
    'Gauribidanur Radio BOservatory, India',
    'Nobeyama Radio Observatory,Nagamo Prefecture,Japan',
    'Badary,Russia: Siberian Solar Radio + Badary Radio Observatory',
    'Galenki, Russia: Gelanki RT-70 radio telescope',
    'Guithou,China: FAST, 500 m radio',
            # Australia
    'Murchison Radio Observatory, Western Australia: ASKAP + MWA',
    'Paul Wild Observatory, New South Wales: ATCA',
    'Tidbinbilla, Capital Teerritoy: Deep Space Communication Complex',
    'Ceduna, Southern Australia: Ceduna Radio Observatory', 
    'Molonglo Observatory Synthesis Telescopes',
    'Hobart, Tasmania,Mount Pleasant Radio Telescope',
    'Parkes Observatory, New South Wales',
            # Europe 
    'Bad Münstereifel: Effelsberg 100 m Radio Telescope + Stockert',
    'Grakovo, Kharkov Ukraine:Uktrain T-shaped Radio telescope',
    'Jodrell Bank Observatory, England: Lovell Telescope + Mark II ',
    'Zelencukskaya, Russia: RATAN 600 ',
    'Kalyazin, Russia: RT-64', 
    'Pushchino, Russia: DKR-1000 & BSA ',
     'Spanish National Observatory Yebes: Yebes RT 40 m',
    'Torún Centre of Astronomy, Poland: Torún RT4 32 m, RT3 15 m ', 
    'Ventspils International Radio Astronomy Center, Latvia: RT32 + RT 16',
    'Medicina Radio Observatory, Italy: Northern Cross Radio + VLBl dish',
    'Noto Radio Observatory, Italy: VLBl dish',
    'Pico Veleta, Granada: IRAM 30 m',
    'Westerbork, Netherlands: Westerbork Synthesis Radio Telescope',
    'Onsala Space Observatory, Sweden: 20&25 m telescope',
    'Yevpatoria Crimea Deep Space: Yevpatoria RT70, Plutoncomplex',
    'Kilpisjärvi, Finnland: KAIRA',
    'Nancay, France: Nacay Radio Telescope, Decameter Array / Radio Heliographe',
    'Mullard Radio Astronomy Observatory, England: Arcminute Microkelvin Imager',
    'The European Radio Astronomy Club Telescope, Mannheim, Germany',
    'The European Radio Astronomy Club Telescope, Elsass, France',
    'The European Radio Astronomy Club Telescope, Lothian, Scotland',
            # North America
    'Algonquin Radio Observatory, Canada: Algonquin Radio Telescope',
    'Hat Creek Radio Observatory, California: Allen Telescope Array',
    'Kitt Peak National Observatory, Arizona: ARO 12 m',
    'Owens Valley Radio Observatory, California: C_BASS North, CARMA,',
    'Dominion Radio Astrophysical Observatory, Canada: CHIME', 
    'Massachusetts USA: FCRAO, Haystack Observatory',
    'Green Band, West Virginia: GBI, GBT, 140 Foot Telescope,',
    'Mount Graham, Arizona: Heinrich Hertz Submillimeter Telescope',
    'Sierra Negra, Mexico: Large Millimeter Telescope',
    'Socorro, New Mexico :Long Wavelength Array, VLBA',
            # South America 
    'Llano de Chajnantor Observatory,Atacama Dessert: ABS,ACT,ALMA,APEX,ASTE, CBI, CLASS',
    'Cachoeira Paulista, Brazil: BDA, Itapetinga',
    'Camplejo Astronomico El Leoncita, Argentina: Solar Submillimeter Telescopes', 
            # Ocean 
    'Observatorio del Teide, Canray Islands: Very Small Array',
    'Arecibo Observatory, Puerto Rico', 
    'Mauritius Radio Telescopes',
    'Manua Kea Observatory, Hawaii: Submillimeter Array, Maxwell Telescopes', 
    'Warkworth Radio Observatory, New Zealand: Warkworth Radio Telescope,2 dish'
         ])

Lambda = np.array(['Radio','Radio','Radio', 'Radio', # Africa
                   'Radio', # Antarctica 
                   'Radio','Radio', 'Radio', 'Radio', 'Radio', 'Radio','Radio','Radio', 'Radio', 'Radio', # Asia
                   'Radio', 'Radio', 'Radio', 'Radio', 'Radio','Radio', 'Radio', # Australia 
                   'Radio','Radio', 'Radio', 'Radio', 'Radio', 'Radio','Radio','Radio',
                   'Radio', 'Radio', 'Radio','Radio', 'Radio', 'Radio', 'Radio', 'Radio',
                   'Radio', 'Radio','Radio', 'Radio', 'Radio', # Europe
                   'Radio', 'Radio','Radio' , 'Radio', 'Radio', 'Radio','Radio',
                   'Radio', 'Radio', 'Radio', 'Radio', 'Radio', 'Radio', #North & South America
                   'Radio', 'Radio', 'Radio', 'Radio', 'Radio', #Oceans 
                  ])
## EAST ##
Lon = np.array([Angle('-1°1′23.498″')/u.deg, # Ghana  
                Angle('22°08′0″')/u.deg,  # Northern Cape / MeerKAT, SKA etc.  
                Angle('27°41′08″')/u.deg,  # Johannesburg Observatory 
                Angle('30°34′20.99″')/u.deg,  # KwaZulu Natal  
                
                Angle('139°16′22.41″')/u.deg,  # Admundson Scott South Pole 
                
                Angle('97°23′0″')/u.deg,  # Qinghai, China 
                121.4737021,  # Shanghai
                Angle('116°50′22″')/u.deg,  # Miyun, China 
                Angle('73°51′24″')/u.deg,  # Pune, India
                76.70,  # Ooty, India
                Angle('77°31′00″')/u.deg,  # Gauribidanur, India
                138.266418,  # Japanese 
                Angle('102°13′08″')/u.deg,  # Russian Siberian
                Angle('131°58′0″')/u.deg,  # Russian Ussuriyk 
                Angle('106°50′0″')/u.deg,  # Guingzu, FAST
                
                Angle('116°39′32″')/u.deg,  # Murchison Radio astronomy Observatory 
                Angle('149°33′43″')/u.deg,  # Paul Wild New South Wales 
                Angle('148°58′54″')/u.deg,  # Canberra Deep Space Complex
                Angle('133°40′0″')/u.deg,  # Ceduna 
                Angle('149°25′26″')/u.deg,  # Molonglo Observatory
                Angle('147°26′20″')/u.deg,  # Tasmania 
                Angle('148°15′47″')/u.deg,  # Parkes 
                
                Angle('6°52′58″')/u.deg,  # Effelsberg,
                Angle('36°56′10″')/u.deg,  # Ukraine
                Angle('-2°18′26″')/u.deg,  # Jordrell Bank GB 
                Angle('41°35′11″')/u.deg,  # Zelenchukskaya, Russia
                Angle('37°53′0″')/u.deg,  # Kalyazin, Russia
                Angle('37°37′0″')/u.deg,  # Puschino, Russia
                Angle('3°40′41″')/u.deg,  # Yebes, Spain 
                Angle('18°33′46″')/u.deg,  # Torún Poland  
                Angle('21°51′18″')/u.deg,  # Ventspils International Latvia 
                Angle('11°38′49″')/u.deg,  # Medicina Italy
                Angle('25°59′21″')/u.deg,  # Noto Radia Italy
                Angle('-3°21′57″')/u.deg,  # Pico Veleta Spain 
                Angle('6°36′12″')/u.deg,  # Westerbrok Netherlands 
                Angle('11°55′04″')/u.deg,  # Onsalle Sweden 
                Angle('33°11′0″')/u.deg,  # Yevpatrona Crimera 
                Angle('24°23′38″')/u.deg,  # Metsähovi Radio Observatory 
                Angle('2°11′43″')/u.deg,  # nancay France 
                Angle('0°01′57″')/u.deg,  # Mullard England 
                Angle('8°28′9″')/u.deg,  # ERAC Mannheim 
                Angle('7°30′0″')/u.deg,  # ERAC France
                Angle('2°45′0″')/u.deg,  # ERAC Scotland 
                
                Angle('-78°04′23″')/u.deg,  # Ontario Canada Algonquin 
                Angle('-121°28′23″')/u.deg,  # Hat Creek Radio California 
                Angle('-111°35′48″')/u.deg, ## Arizona Kitt Peak
                Angle('-118°16′55″')/u.deg, ## Owens Valley California
                Angle('-119°37′26″')/u.deg, # Dominion Okanagn Falls Canada 
                -71.8, # Massachusetts
                Angle('-79°49′53″')/u.deg, # Green Bank 
                Angle('-109°53′31″')/u.deg, ## Arizona Graham
                Angle('-97°18′53″')/u.deg, ## Mexiko 
                Angle('-107°38′0″')/u.deg, ## New Mexiko
                
                Angle('-67°45′18″')/u.deg, # Atacama Dessert 
                Angle('-46°33′02″')/u.deg, # Brazil 
                -69.2956, # Argentina 
                
                Angle('-16°30′35″')/u.deg, # Canary Islands  
                Angle('-66°45′10″')/u.deg, # Arecibo 
                Angle('57°43′31″')/u.deg, # Mauritius
                Angle('-155°28′30″')/u.deg, # Manua Kea Observatory 
                174.6669024, # New Zealand 
      ])

## NORTH ##
Lat = np.array([Angle('7°56′47.497″')/u.deg,# Ghana 
                Angle('-30°58′0″')/u.deg,# Northern Cape / MeerKAT, SKA etc. 
                Angle('-25°53′25″')/u.deg,  # Johannesburg Observatory 
                Angle('-30°34′20″')/u.deg,  # KwaZulu Natal
                
                Angle('-88°59′51.19″')/u.deg,  # Admundson Scott South Pole
                
                Angle('37°23′0″')/u.deg,  # Qinghai, China 
                31.2303904,  # Shanghai 
                Angle('40°22′28″')/u.deg,  # Miyun, China 
                Angle('18°31′13″')/u.deg,  # Pune, India
                11.41,  # Ooty, India
                Angle('13°36′40″')/u.deg,  # Gauribidanur, India
                36.255486,  # Japanese 
                Angle('51°45′33″')/u.deg,  # Russian Siberian
                 Angle('43°48′0″')/u.deg,  # Russian Ussuriyk 
                Angle('26°50′0″')/u.deg,  # Guingzu, FAST
                
                Angle('-26°42′15″')/u.deg,  # Murchison Radio astronomy Observatory 
                Angle('-30°18′50″')/u.deg,  # Paul Wild New South Wales 
                Angle('35°24′05″')/u.deg,  # Canberra Deep Space Complex
                Angle('-32°07′0″')/u.deg,  # Ceduna
                Angle('-35°22′15″')/u.deg,  # Molonglo Observatory
                Angle('-42°48′18″')/u.deg,  # Tasmania 
                Angle('-32°59′52″')/u.deg,  # Parkes
                
                Angle('50°31′29″')/u.deg,  # Effelsberg
                Angle('49°38′17″')/u.deg,  # Ukraine 
                Angle('53°14′10″')/u.deg,  # Jordrell Bank GB 
                Angle('43°49′33″')/u.deg,  # Zelenchukskaya, Russia 
                Angle('57°14′0″')/u.deg,  # Kalyazin, Russia
                Angle('54°50′0″')/u.deg,  # Puschino, Russia
                Angle('40°24′40″')/u.deg,  # Yebes, Spain 
                Angle('53°05′43″')/u.deg,  # Torún Poland 
                Angle('57°33′13″')/u.deg,  # Ventspils International Latvia
                Angle('44°31′15″')/u.deg,  # Medicina Italy
                Angle('36°52′34″')/u.deg,  # Noto Radia Italy
                Angle('37°3′24″')/u.deg,  # Pico Veleta Spain 
                Angle('52°54′53″')/u.deg,  # Westerbrok Netherlands 
                Angle('57°23′35″')/u.deg,  # Onsalle Sweden 
                Angle('45°11′0″')/u.deg,  # Yevpatrona Crimera
                Angle('60°13′05″')/u.deg,  # Metsähovi Radio Observatory
                Angle('47°21′02″')/u.deg,  # nancay France 
                Angle('52°10′03″')/u.deg,  # Mullard England 
                Angle('49°29′20″')/u.deg,  # ERAC Mannheim 
                Angle('48°30′0″')/u.deg,  # ERAC France
                Angle('55°55′0″')/u.deg,  # ERAC Scotland 
                
                Angle('45°57′20″')/u.deg,  # Ontario Canada Algonquin 
                Angle('40°49′04″')/u.deg,  # Hat Creek Radio California 
                Angle('31°57′30″')/u.deg, ## Arizona Kitt Peak
                Angle('37°14′02″')/u.deg, ## Owens Valley California
                Angle('49°19′16″')/u.deg, # Dominion Canada 
                42.3, # Massachusetts 
                Angle('38°25′12″')/u.deg, # Green Bank
                Angle('32°42′05″')/u.deg, ## Arizona 
                Angle('18°59′09″')/u.deg, ## Mexiko
                Angle('34°04′0″')/u.deg, ## New Mexiko
                
                Angle('-23°01′22″')/u.deg, # Atacama Dessert
                Angle('-23°07′02″')/u.deg, # Brazil 
                -31.7986, # Argentina 
                
                Angle('28°18′00″')/u.deg, # Canary Islands 
                Angle('18°20′39″')/u.deg, # Arecibo 
                Angle('20°08′21″')/u.deg, # Mauritius
                Angle('19°49′20″')/u.deg, # Manua Kea Observatory
                -36.4324309, # New Zealand 
               ])

df_Radio = pd.DataFrame(OrderedDict({'Observatory': Obs,'Wavelength': Lambda, 'Longitude_East': Lon, 'Latitude_North': Lat}))
#df_Radio

# %%
##  Gamma 
Obs = np.array(['Roque de los Muchahos, Canary Islands: MAGIC Telescopes',
                'Whipple Observatory: VERITAS',
                'Sierra Negra: HAWC',
                'Khomas Region, Namibia: H.E.S.S. array',
                'Paranal, Chile: CTA', 
                'La Palma, Canary Islands : CTA',
                'Indian Astronomical Observatory: MACE'    
               ])


Lambda = np.array(['Gamma','Gamma','Gamma and Cosmic Rays', 'Gamma',
                   'Gamma', 'Gamma', 'Gamma', 
               ])
## EAST ##
Lon = np.array([Angle('-17°53′24″')/u.deg, # La Palma 
                Angle('-110°57′07″')/u.deg, # Whipple, VERITAS 
                Angle('-97°18′30.6″')/u.deg, # HAWC 
                Angle('16°30′00″')/u.deg, # H.E.S.S. namibia
                Angle('-70°24′11″')/u.deg, ## Chile 
                Angle('-17°53′5″')/u.deg,  ## La palma 
                Angle('78°58′00″')/u.deg,  ## India, MACE  
               ])

## NORTH ##
Lat = np.array([Angle('28°45′43″')/u.deg,# La Palma  
                Angle('31°40′30″')/u.deg, # Whipple
                 Angle('18°59′41″')/u.deg, # HAWC
                Angle('-23°16′17″')/u.deg, # H.E.S.S. namibia 
                Angle('-24°37′18″')/u.deg, # Chile 
                Angle('28°45′15″')/u.deg, # La Palma
                Angle('32°47′00″')/u.deg,  ## India, MACE  
               ])

df_Gamma = pd.DataFrame(OrderedDict({'Observatory': Obs,'Wavelength': Lambda, 'Longitude_East': Lon, 'Latitude_North': Lat}))
#df_Gamma

# %%
## Cosmic Rays
Obs = np.array(['Malargue, Argentina: Pierre Auger Observatory',
                'Sierra Negra: HAWC',
                'Millard Country, Utah: Telescope Array Project',
               'Seattle: Washington Large Area Time Coincidence Arrray',
                'Brookhaven National Laboratory: MARIACHI',
                'Mount Aragats. Armenia: GAMMA',
                'California Institute of Technology in Pasedena: CHICOS',
                'Tata Institude of Fundamental Research, India: GRAPES-3'
               ])

Lambda = np.array(['Cosmic Rays','Cosmic Rays (and Gamma)', 'Cosmic Rays, Gammas', 
                   'Comsic Rays', 'Cosmic Rays', 'Cosmic Rays, Gamma',
                   'Cosmic Rays', 'Cosmic Rays', 
               ])
## EAST ##
Lon = np.array([-69.31597, # Argentina
                Angle('-96°18′30.6″')/u.deg, # HAWC 
                Angle('-112°54′31″')/u.deg, # Telescope Array 
                Angle('-122°19′59″')/u.deg, # WALTA 
                -72.877, # MARIACHI 
                Angle('44°12′00″')/u.deg, # GAMMA, Armenia 
               -118.125, # Chicos, California 
                76.7, # GRAPES India Ooty  
              ])

## NORTH ##
Lat = np.array([-35.20675,# Argentina 
                Angle('17°59′41″')/u.deg, # HAWC
                Angle('39°17′49″')/u.deg, # Telescope Array 
                Angle('47°36′35″')/u.deg, # WALTA 
                40.875, # MARIACHI 
                Angle('40°32′00″')/u.deg, # GAMMA, Armenia 
                34.138, # Chicos, California 
               11.4, # GRAPES India Ooty  
                          ])

df_Cos = pd.DataFrame(OrderedDict({'Observatory': Obs,'Wavelength': Lambda, 'Longitude_East': Lon, 'Latitude_North': Lat}))
#df_Cos

# %%
## Neutrino 
Obs = np.array(['Mediterranean Sea, France: ANTARES',
                'Ross Ice Shelf, Antarctica: ARIANNA',
                'Lake Baikal, Russia: BDUNT',
                'South Pile Starion, Antarctica: IceCube', 
                'Gran Sasso, Italy:  ICARUS', 
                'Mediterranean Sea: KM3NeT',
                'Kamioka, Japan: Super-Kamiokande'
])


Lambda = np.array(['Neutrino', 'Neutrino', 'Neutrino', 'Neutrino', 'Neutrino','Neutrino',
                   'Neutrino', 
       ])
## EAST ##
Lon = np.array([Angle('6°10′00″')/u.deg, # Antares
                Angle('-175°00′00″')/u.deg, # Arianna
                Angle('104°23′52″')/u.deg, # BDUNT, Russia 
                Angle('-63°27′11″')/u.deg, # ICe CUbe  
                 Angle('13°33′00″')/u.deg, # Gran Sasso  
                18, # Mediterranean Sea 
               Angle('137°18′37.1″')/u.deg, # Japan, Super-K
           ])

## NORTH ##
Lat = np.array([Angle('42°48′00″')/u.deg, # Antares 
                Angle('-81°30′00″')/u.deg, # Arianna
                Angle('51°46′17″')/u.deg, # BDUNT, Russia 
                 Angle('-89°59′24″')/u.deg, # ICe CUbe 
                Angle('42°28′00″')/u.deg, # Gran Sasso
                35, # Mediterranean Sea 
                Angle('36°25′32.6″')/u.deg, # Japan, Super-K
           ])


df_N = pd.DataFrame(OrderedDict({'Observatory': Obs,'Wavelength': Lambda, 'Longitude_East': Lon, 'Latitude_North': Lat}))
#df_N

# %%
## English 
fig = plt.figure(figsize=(10, 6), edgecolor='w')
m = Basemap(projection='cyl',llcrnrlat=-90,urcrnrlat=90,\
            llcrnrlon=-180,urcrnrlon=180,resolution='c')
m.drawcoastlines(color='#73ac14')
m.fillcontinents(color='#73ac14',alpha=0.5,lake_color='lightsteelblue')
m.drawparallels(np.arange(-90.,91.,30.),labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,181.,60.),labels=[0,0,0,1])
m.drawmapboundary(fill_color='lightsteelblue')

m.plot(df_Radio['Longitude_East'],df_Radio['Latitude_North'],'+',ms=4,color='indigo', label='Radio Instruments')
m.plot(df_Cos['Longitude_East'],df_Cos['Latitude_North'],'o',ms=4,color='thistle', label='Cosmic Ray Observatories')
m.plot(df_N['Longitude_East'],df_N['Latitude_North'],'x',ms=6,color='darkmagenta', label='Neutrino Experiments')
m.plot(df_Optical['Longitude_East'][2:25],df_Optical['Latitude_North'][2:25],'*',ms=4,color='mediumpurple', label='Optical Instruments with eff. aperture > 3.6 m') 


m.plot(df_Gamma['Longitude_East'],df_Gamma['Latitude_North'],'s',ms=4,color='dimgray', label='Gamma-ray Instruments')
m.plot(-17.89,28.76,'o',color='dimgray',alpha=0.5, ms=12,label='CTA North')
m.plot(Angle('-70°24′15″')/u.deg,Angle('-24°37′38″')/u.deg,'s',color='dimgray', alpha=0.5,ms=12, label='CTA South')

plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0., fontsize = 10.5)
plt.savefig('Plots/Different_Telescopes.pdf',bbox_to_anchor = 'tight')
#plt.savefig('Plots/jpeg/Different_Telescopes.jpeg')
plt.show()
# Out:
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
## Deutsch
cmap = plt.cm.get_cmap('viridis')
viridis8 = cmap(0.28)
viridis7 = cmap(0.35)
fig = plt.figure(figsize=(10, 6), edgecolor='w')
m = Basemap(projection='cyl',llcrnrlat=-90,urcrnrlat=90,\
            llcrnrlon=-180,urcrnrlon=180,resolution='c')
m.drawcoastlines(color='#73ac14')
m.fillcontinents(color='#73ac14',alpha=0.5,lake_color='lightsteelblue')
m.drawparallels(np.arange(-90.,91.,30.),labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,181.,60.),labels=[0,0,0,1])
m.drawmapboundary(fill_color='lightsteelblue')

m.plot(df_Radio['Longitude_East'],df_Radio['Latitude_North'],'+',ms=5,color='indigo', label='Radio Instrumente')
m.plot(df_Cos['Longitude_East'],df_Cos['Latitude_North'],'o',ms=5,color='thistle', label='Cosmic Ray Observatorien')
m.plot(df_N['Longitude_East'],df_N['Latitude_North'],'x',ms=6,color='darkmagenta', label='Neutrino Experimente')
m.plot(df_Optical['Longitude_East'][2:25],df_Optical['Latitude_North'][2:25],'*',ms=5,color='mediumpurple', label='Optische Instrumente mit eff. Öffnung > 3.6 m') 


m.plot(df_Gamma['Longitude_East'],df_Gamma['Latitude_North'],'s',ms=4,color='dimgray', label='Gamma-ray Instrumente')
m.plot(-17.89,28.76,'o',color='dimgray',alpha=0.5, ms=10,label='CTA Nord')
m.plot(Angle('-70°24′15″')/u.deg,Angle('-24°37′38″')/u.deg,'s',color='dimgray', alpha=0.5,ms=10, label='CTA Süd')
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0., fontsize = 10.5)
plt.savefig('Plots/Different_Telescopes_DE.pdf',bbox_to_anchor = 'tight')
plt.show()
# Out:
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1698: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
from itertools import chain

def draw_map(m, scale=0.2):
    # draw a shaded-relief image
    m.shadedrelief(scale=scale)
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, 6),labels=[1,0,0,0])
    lons = m.drawmeridians(np.linspace(-180, 180, 6),labels=[0,0,0,1])
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution=None,
            llcrnrlat=-90, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)

mlin = np.linspace(-180,180)
m.plot(mlin,0*mlin,'--', color='tan')

m.plot(-17.89,28.76,'o',color='tan', ms=12,label='CTA North')
m.plot(Angle('-70°24′15″')/u.deg,Angle('-24°37′38″')/u.deg,'s',color='tan',ms=12, label='CTA South')
m.plot(df_Optical['Longitude_East'],df_Optical['Latitude_North'],'*',color='dimgray', label= 'Largest telescopes in multiwavelengths')
plt.legend(loc = 'lower right',bbox_to_anchor=(1.01, 1.05),ncol=1)
m.plot(df_Radio['Longitude_East'],df_Radio['Latitude_North'],'*',color='dimgray') 
m.plot(df_Gamma['Longitude_East'],df_Gamma['Latitude_North'],'*',color='dimgray')
m.plot(df_Cos['Longitude_East'],df_Cos['Latitude_North'],'*',color='dimgray')
m.plot(df_N['Longitude_East'],df_N['Latitude_North'],'*',color='dimgray')
plt.savefig('Plots/All_Telescopes.pdf')
# Out:
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3296: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3305: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
m = Basemap(projection='moll',lon_0=0,resolution='c')
m.drawcoastlines(color='#73ac14')
m.fillcontinents(color='#73ac14',alpha=0.5,lake_color='lightsteelblue')
# draw parallels and meridians.
m.drawparallels(np.arange(-90.,90.,30.),alpha=0.5)
m.drawmeridians(np.arange(-180.,180.,60.),alpha=0.5)
m.drawmapboundary(fill_color='lightsteelblue')

x,y = np.zeros(len(df_Optical['Longitude_East'])),np.zeros(len(df_Optical['Longitude_East']))
for i in range(0,len(df_Optical['Longitude_East'])):
    x[i],y[i] = m(df_Optical['Longitude_East'][i],df_Optical['Latitude_North'][i])
m.plot(x,y,'*',ms=4,color='k', label='Optical Instruments with eff. aperture > 3.6 m')


x,y = np.zeros(len(df_Gamma['Longitude_East'])),np.zeros(len(df_Gamma['Longitude_East']))
for i in range(0,len(df_Gamma['Longitude_East'])):
    x[i],y[i] = m(df_Gamma['Longitude_East'][i],df_Gamma['Latitude_North'][i])
m.plot(x,y,'*',ms=4,color='k', label='Gamma-ray experiments')


x,y = np.zeros(len(df_Radio['Longitude_East'])),np.zeros(len(df_Radio['Longitude_East']))
for i in range(0,len(df_Radio['Longitude_East'])):
    x[i],y[i] = m(df_Radio['Longitude_East'][i],df_Radio['Latitude_North'][i])
m.plot(x,y,'*',ms=4,color='k', label='Radio interferometers')
plt.savefig('Plots/Mollweide.pdf')
# Out:
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1623: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   fill_color = ax.get_axis_bgcolor()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3260: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/jana/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3269: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
